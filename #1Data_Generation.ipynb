# %% [markdown]
# Option 1 -  Crawl news & information websites & anticipate the likelihood of its virality.

# %%
#Using twitterscraper API for mining tweets

from twitterscraper import query_tweets
import datetime as dt
import pandas as pd
# Out:
# INFO: {'User-Agent': 'Opera/9.80 (X11; Linux i686; Ubuntu/14.10) Presto/2.12.388 Version/12.16'}

# %%
#Using begin and end dates for mining recent tweets
begin_date = dt.date(2020,3,1) 
end_date = dt.date(2020,4,21)
limit = 3000
lang = 'English'

# %%
#Tweets in Hyderabad area about corona or corona virus
hyd_tweets = query_tweets(begindate=begin_date, enddate=end_date,limit=limit, lang=lang, query='Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:Hyderabad within:mi' )
# Out:
# INFO: queries: ['Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:Hyderabad within:500mi since:2020-03-01 until:2020-03-03', 'Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:Hyderabad within:500mi since:2020-03-03 until:2020-03-06', 'Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:Hyderabad within:500mi since:2020-03-06 until:2020-03-08', 'Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:Hyderabad within:500mi since:2020-03-08 until:2020-03-11', 'Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:Hyderabad within:500mi since:2020-03-11 until:2020-03-13', 'Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:Hyderabad withi
# ...

# %%
hyd_df = pd.DataFrame(t.__dict__ for t in hyd_tweets)

# %%
#checking hyderabad tweets
hyd_df.describe()
# Out:
#        timestamp_epochs          likes      retweets       replies
# count      4.802000e+03    4802.000000   4802.000000   4802.000000
# mean       1.585606e+09     436.023324    147.158059     22.683049
# std        1.211177e+06    3056.209088   1410.168903    299.025321
# min        1.583036e+09       8.000000      0.000000      0.000000
# 25%        1.584680e+09      50.000000     21.000000      2.000000
# 50%        1.585549e+09      99.500000     34.000000      5.000000
# 75%        1.586721e+09     239.000000     71.000000     13.000000
# max        1.587427e+09  151021.000000  60354.000000  19546.000000

# %%
df['retweets'].describe()
# Out:
# count    1063.000000
# mean        0.835372
# std         4.554771
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max        71.000000
# Name: retweets, dtype: float64

# %%
mumbai_tweets = query_tweets(begindate=begin_date, enddate=end_date,limit=limit, lang=lang, query='Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:Mumbai within:200mi' )
# Out:
# INFO: queries: ['Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:Mumbai within:200mi since:2020-03-01 until:2020-03-03', 'Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:Mumbai within:200mi since:2020-03-03 until:2020-03-06', 'Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:Mumbai within:200mi since:2020-03-06 until:2020-03-08', 'Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:Mumbai within:200mi since:2020-03-08 until:2020-03-11', 'Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:Mumbai within:200mi since:2020-03-11 until:2020-03-13', 'Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:Mumbai within:200mi since:2020
# ...

# %%
mum_df = pd.DataFrame(t.__dict__ for t in mumbai_tweets)

# %%
mum_df.describe()
# Out:
#        timestamp_epochs          likes      retweets       replies
# count      1.805000e+03    1805.000000   1805.000000   1805.000000
# mean       1.586347e+09     568.665374    157.120222     45.874238
# std        1.195982e+06    3358.374060   1164.652264    654.934983
# min        1.583042e+09      10.000000      8.000000      0.000000
# 25%        1.585465e+09      49.000000     18.000000      2.000000
# 50%        1.587030e+09     108.000000     32.000000      6.000000
# 75%        1.587312e+09     292.000000     72.000000     17.000000
# max        1.587418e+09  115470.000000  42645.000000  19546.000000

# %%
delhi_tweets = query_tweets(begindate=begin_date, enddate=end_date,limit=limit, lang=lang, query='Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:Delhi within:200mi ' )
# Out:
# INFO: queries: ['Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:Delhi within:200mi  since:2020-03-01 until:2020-03-03', 'Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:Delhi within:200mi  since:2020-03-03 until:2020-03-06', 'Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:Delhi within:200mi  since:2020-03-06 until:2020-03-08', 'Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:Delhi within:200mi  since:2020-03-08 until:2020-03-11', 'Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:Delhi within:200mi  since:2020-03-11 until:2020-03-13', 'Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:Delhi within:200mi  since:2020
# ...

# %%
del_df = pd.DataFrame(t.__dict__ for t in delhi_tweets)

# %%
del_df.describe()
# Out:
#        timestamp_epochs          likes      retweets      replies
# count      1.565000e+03    1565.000000   1565.000000  1565.000000
# mean       1.585572e+09     583.790415    138.428754    25.272843
# std        1.257437e+06    5548.185803    924.570151   200.578528
# min        1.583039e+09      11.000000      6.000000     0.000000
# 25%        1.584630e+09      49.000000     21.000000     2.000000
# 50%        1.585558e+09      91.000000     34.000000     5.000000
# 75%        1.586766e+09     226.000000     73.000000    13.000000
# max        1.587425e+09  151021.000000  24420.000000  5389.000000

# %%
banglore_tweets = query_tweets(begindate=begin_date, enddate=end_date,limit=limit, lang=lang, query='Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:Bangalore within:400mi ' )
# Out:
# INFO: queries: ['Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:Bangalore within:400mi  since:2020-03-01 until:2020-03-03', 'Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:Bangalore within:400mi  since:2020-03-03 until:2020-03-06', 'Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:Bangalore within:400mi  since:2020-03-06 until:2020-03-08', 'Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:Bangalore within:400mi  since:2020-03-08 until:2020-03-11', 'Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:Bangalore within:400mi  since:2020-03-11 until:2020-03-13', 'Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:Bangalore 
# ...

# %%
banglore_df = pd.DataFrame(t.__dict__ for t in banglore_tweets)

# %%
banglore_df.describe()
# Out:
#        timestamp_epochs        likes     retweets     replies
# count      7.630000e+02   763.000000   763.000000  763.000000
# mean       1.586012e+09   347.507208    66.816514   12.385321
# std        1.271624e+06   652.932417   103.461458   27.427612
# min        1.583037e+09    11.000000     9.000000    0.000000
# 25%        1.584979e+09    62.000000    19.000000    2.000000
# 50%        1.586234e+09   126.000000    33.000000    5.000000
# 75%        1.587142e+09   301.000000    75.000000   11.500000
# max        1.587427e+09  5381.000000  1163.000000  365.000000

# %%
chennai_tweets = query_tweets(begindate=begin_date, enddate=end_date,limit=limit, lang=lang, query='Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:chennai within:500mi ' )
# Out:
# INFO: queries: ['Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:chennai within:500mi  since:2020-03-01 until:2020-03-03', 'Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:chennai within:500mi  since:2020-03-03 until:2020-03-06', 'Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:chennai within:500mi  since:2020-03-06 until:2020-03-08', 'Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:chennai within:500mi  since:2020-03-08 until:2020-03-11', 'Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:chennai within:500mi  since:2020-03-11 until:2020-03-13', 'Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:chennai within:500mi
# ...

# %%
chennai_df = pd.DataFrame(t.__dict__ for t in chennai_tweets)

# %%
chennai_df.describe()
# Out:
#        timestamp_epochs          likes      retweets      replies
# count      2.997000e+03    2997.000000   2997.000000  2997.000000
# mean       1.585352e+09     420.062062    166.938939    23.321989
# std        1.242494e+06    3039.461395   1671.589350   133.549242
# min        1.583027e+09       6.000000      7.000000     0.000000
# 25%        1.584374e+09      51.000000     22.000000     2.000000
# 50%        1.585410e+09     100.000000     35.000000     5.000000
# 75%        1.586355e+09     249.000000     76.000000    14.000000
# max        1.587427e+09  151021.000000  60349.000000  5389.000000

# %%
kerala_tweets = query_tweets(begindate=begin_date, enddate=end_date,limit=limit, lang=lang, query='Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:kerala within:500mi ' )
# Out:
# INFO: queries: ['Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:kerala within:500mi  since:2020-03-01 until:2020-03-03', 'Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:kerala within:500mi  since:2020-03-03 until:2020-03-06', 'Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:kerala within:500mi  since:2020-03-06 until:2020-03-08', 'Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:kerala within:500mi  since:2020-03-08 until:2020-03-11', 'Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:kerala within:500mi  since:2020-03-11 until:2020-03-13', 'Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:kerala within:500mi  sinc
# ...

# %%
gujrat_tweets = query_tweets(begindate=begin_date, enddate=end_date,limit=limit, lang=lang, query='Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:gujrat within:500mi ' )
# Out:
# INFO: queries: ['Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:gujrat within:500mi  since:2020-03-01 until:2020-03-03', 'Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:gujrat within:500mi  since:2020-03-03 until:2020-03-06', 'Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:gujrat within:500mi  since:2020-03-06 until:2020-03-08', 'Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:gujrat within:500mi  since:2020-03-08 until:2020-03-11', 'Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:gujrat within:500mi  since:2020-03-11 until:2020-03-13', 'Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona  OR coronago min_retweets:10 min_faves:10 near:gujrat within:500mi  sinc
# ...

# %%
kerala_df = pd.DataFrame(t.__dict__ for t in kerala_tweets)
gujrat_df = pd.DataFrame(t.__dict__ for t in gujrat_tweets)

# %%
#concatenating tweets of different cities
df = pd.concat([hyd_df, mum_df, banglore_df, del_df, kerala_df, gujrat_df])

# %%
df.describe()
# Out:
#        timestamp_epochs          likes      retweets       replies
# count      1.187200e+04   11872.000000  11872.000000  11872.000000
# mean       1.585707e+09     475.225152    137.764319     26.006149
# std        1.257154e+06    3453.769391   1180.292508    334.858053
# min        1.583036e+09       8.000000      0.000000      0.000000
# 25%        1.584712e+09      50.000000     20.000000      2.000000
# 50%        1.585733e+09     101.000000     34.000000      5.000000
# 75%        1.587028e+09     253.000000     72.000000     14.000000
# max        1.587427e+09  151021.000000  60354.000000  19546.000000

# %% [markdown]
# Tweets from different cities are collected and concatenated

# %%
#
df.head()
# Out:
#     screen_name                                     username     user_id  \
# 0  Clinical_Sim  الطب والمحاكاة #كلنا_مسؤول ... Clinical Sim  2421885032
# 1     AlexInAir                                Alex Macheras   191881312
# 2    KVishReddy                      Konda Vishweshwar Reddy  1125085620
# 3    one_by_two                                  Atul Khatri    28515858
# 4    one_by_two                                  Atul Khatri    28515858
#
#               tweet_id                                 tweet_url  \
# 0  1234560981763854336  /Clinical_Sim/status/1234560981763854336
# 1  1234533775809351681     /AlexInAir/status/1234533775809351681
# 2  1234531413191299073    /KVishReddy/status/1234531413191299073
# 3  1234515105620144129    /one_by_two/status/1234515105620144129
# 4  1234514105102471175    /one_by_two/status/1234514105102471175
#
#             timestamp  timestamp_epochs  \
# 0 2020-03-02 19:27:29        1583177249
# 1 2020-03-02 17:39:23        1583170763
# ...

# %%
df_dup=df.drop_duplicates(subset ="tweet_id", keep=False,inplace=True)

# %%
df.describe()
# Out:
#        timestamp_epochs         likes      retweets      replies
# count      2.375000e+03   2375.000000   2375.000000  2375.000000
# mean       1.586487e+09    386.436632    152.181053    17.922526
# std        1.115549e+06   1586.129907   1393.005278    65.215190
# min        1.583043e+09     10.000000      0.000000     0.000000
# 25%        1.585553e+09     50.000000     18.000000     1.000000
# 50%        1.587115e+09     99.000000     30.000000     4.000000
# 75%        1.587329e+09    232.000000     60.500000    11.000000
# max        1.587422e+09  31800.000000  60354.000000  1197.000000

# %%
df.head()
# Out:
#        screen_name               username              user_id  \
# 32      mbah_mijan             Mbah Mijan            227961909
# 53   SriLankaTweet     Sri Lanka Tweet 🇱🇰             41786801
# 94     babblingnia  Nia Bebel #StayAtHome  1131926153474654209
# 124  neyrashazeyra      Penjual Sanitizer             22664411
# 130       yaashjay                  yaash           1210815386
#
#                 tweet_id                                  tweet_url  \
# 32   1234382734123917312     /mbah_mijan/status/1234382734123917312
# 53   1233998380398972928  /SriLankaTweet/status/1233998380398972928
# 94   1236217732065939456    /babblingnia/status/1236217732065939456
# 124  1235823254268329985  /neyrashazeyra/status/1235823254268329985
# 130  1235747618187141120       /yaashjay/status/1235747618187141120
#
#               timestamp  timestamp_epochs  \
# 32  2020-03-02 07:39:12        1583134752
# 53  2020-03-01 06:11:55        1583043115
# 94  2020-03-07 09:10:49        1583572249
# ...

# %%
df2 = pd.concat([hyd_df, mum_df, banglore_df, del_df, kerala_df, gujrat_df])

# %%
df2=df2.drop_duplicates(subset ='tweet_id')

# %%
df2.describe()
# Out:
#        timestamp_epochs          likes      retweets       replies
# count      5.742000e+03    5742.000000   5742.000000   5742.000000
# mean       1.585956e+09     444.274643    144.626611     23.352490
# std        1.251563e+06    2907.280274   1306.269770    278.483762
# min        1.583036e+09       8.000000      0.000000      0.000000
# 25%        1.584894e+09      49.000000     19.000000      2.000000
# 50%        1.586091e+09     100.000000     33.000000      5.000000
# 75%        1.587142e+09     243.750000     68.000000     13.000000
# max        1.587427e+09  151021.000000  60354.000000  19546.000000

# %%
df2.head()
# Out:
#     screen_name                                     username     user_id  \
# 0  Clinical_Sim  الطب والمحاكاة #كلنا_مسؤول ... Clinical Sim  2421885032
# 1     AlexInAir                                Alex Macheras   191881312
# 2    KVishReddy                      Konda Vishweshwar Reddy  1125085620
# 3    one_by_two                                  Atul Khatri    28515858
# 4    one_by_two                                  Atul Khatri    28515858
#
#               tweet_id                                 tweet_url  \
# 0  1234560981763854336  /Clinical_Sim/status/1234560981763854336
# 1  1234533775809351681     /AlexInAir/status/1234533775809351681
# 2  1234531413191299073    /KVishReddy/status/1234531413191299073
# 3  1234515105620144129    /one_by_two/status/1234515105620144129
# 4  1234514105102471175    /one_by_two/status/1234514105102471175
#
#             timestamp  timestamp_epochs  \
# 0 2020-03-02 19:27:29        1583177249
# 1 2020-03-02 17:39:23        1583170763
# ...

# %%
#Collecting more tweets
telangana_twts = query_tweets(begindate=begin_date, enddate=end_date,limit=limit, lang=lang, query='Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona OR hyderabad OR people OR coronago min_retweets:10 min_faves:10 near:Telangana within:500mi ' )
# Out:
# INFO: queries: ['Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona OR hyderabad OR people OR coronago min_retweets:10 min_faves:10 near:Telangana within:500mi  since:2020-03-01 until:2020-03-03', 'Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona OR hyderabad OR people OR coronago min_retweets:10 min_faves:10 near:Telangana within:500mi  since:2020-03-03 until:2020-03-06', 'Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona OR hyderabad OR people OR coronago min_retweets:10 min_faves:10 near:Telangana within:500mi  since:2020-03-06 until:2020-03-08', 'Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona OR hyderabad OR people OR coronago min_retweets:10 min_faves:10 near:Telangana within:500mi  since:2020-03-08 until:2020-03-11', 'Corona OR Coronavirus OR Police OR mask OR #corona OR #gocorona OR hyderabad OR people OR coronago min_retweets:10 min_faves:10 near:Telangana within:500mi  since:2020-03-11 until:2020-03-13', 'Corona OR C
# ...

# %%
tel_df = pd.DataFrame(t.__dict__ for t in telangana_twts)

# %%
blr_twts = query_tweets(begindate=begin_date, enddate=end_date,limit=4000, lang=lang, query='min_retweets:10 min_faves:10 near:Bangalore within:500mi ' )
# Out:
# INFO: queries: ['min_retweets:10 min_faves:10 near:Bangalore within:500mi  since:2020-03-01 until:2020-03-03', 'min_retweets:10 min_faves:10 near:Bangalore within:500mi  since:2020-03-03 until:2020-03-06', 'min_retweets:10 min_faves:10 near:Bangalore within:500mi  since:2020-03-06 until:2020-03-08', 'min_retweets:10 min_faves:10 near:Bangalore within:500mi  since:2020-03-08 until:2020-03-11', 'min_retweets:10 min_faves:10 near:Bangalore within:500mi  since:2020-03-11 until:2020-03-13', 'min_retweets:10 min_faves:10 near:Bangalore within:500mi  since:2020-03-13 until:2020-03-16', 'min_retweets:10 min_faves:10 near:Bangalore within:500mi  since:2020-03-16 until:2020-03-18', 'min_retweets:10 min_faves:10 near:Bangalore within:500mi  since:2020-03-18 until:2020-03-21', 'min_retweets:10 min_faves:10 near:Bangalore within:500mi  since:2020-03-21 until:2020-03-23', 'min_retweets:10 min_faves:10 near:Bangalore within:500mi  since:2020-03-23 until:2020-03-26', 'min_retweets:10 min_faves:10 ne
# ...

# %%
blr_df = pd.DataFrame(t.__dict__ for t in blr_twts)

# %%
data = pd.concat([df2, tel_df, blr_df])

# %%
#As the scraper also generates duplicate values, we are removing the duplicate values
data=data.drop_duplicates(subset ='tweet_id')

# %%
data.describe()
# Out:
#        timestamp_epochs          likes      retweets       replies
# count      1.048300e+04   10483.000000  10483.000000  10483.000000
# mean       1.585654e+09     386.286845    147.298674     23.086616
# std        1.314549e+06    2344.392119   1252.141364    217.155543
# min        1.583031e+09       3.000000      0.000000      0.000000
# 25%        1.584591e+09      47.000000     20.000000      2.000000
# 50%        1.585666e+09      97.000000     35.000000      5.000000
# 75%        1.587021e+09     237.000000     73.000000     14.000000
# max        1.587427e+09  151021.000000  60354.000000  19546.000000

# %%
data['retweets'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        52
# 1        24
# 2       176
# 3       185
# 4        56
#        ...
# 4172     30
# 4173     35
# 4174     18
# 4175    741
# 4176     20
# Name: retweets, Length: 10483, dtype: int64>

# %%
data.to_csv (r'C:\Users\vamshi\Documents\Scrape\tweets.csv', index = False, header=True)

# %%
user_name_list = data['screen_name'].t

# %%
user_name_list = list(user_name_list)

# %%
print(user_name_list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-105-afc8663e1caf> in <module>
# ----> 1 print(user_name_list)
#
# c:\users\vamshi\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in head(self, n)
#    4733         """
#    4734
# -> 4735         return self.iloc[:n]
#    4736
#    4737     def tail(self, n=5):
#
# c:\users\vamshi\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1422
#    1423             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1424             return self._getitem_axis(maybe_callable, axis=axis)
#    1425
#    1426     def _is_scalar_access(self, key: Tuple):
#
# c:\users\vamshi\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
# ...

# %%
type(user_name_list)
# Out:
# list

# %%
user_name_list[:20]
# Out:
# ['Clinical_Sim',
#  'AlexInAir',
#  'KVishReddy',
#  'one_by_two',
#  'JebiMather',
#  'NNN_TNP',
#  'prasarbharati',
#  'YohanesPatty2',
#  'thehaelyn',
#  'SAFE_JOHNY',
#  'srijanpalsingh',
#  'Zayed_U',
#  'manateedugong',
#  'mbah_mijan',
#  'ShaikhHamzaIMS',
#  'IamOnir',
#  'RiaRevealed',
#  'CPEC_CSCEC',
#  'dbeasley1',
#  'svirtuoso2010']

# %%
len(user_name_list)
# Out:
# 4631

# %% [markdown]
# We collected over 10,000 tweets from 4631 users. Tweets are mainly about corona we could also collect tweets related to any other topics, we can also specify different hashtags, locations, retweet counts etc.

# %% [markdown]
# These tweets are saved in csv file "tweets.csv"

# %% [markdown]
# As we can see, we could only mine the tweets and information related to a particular tweet, we also need additional information regarding the user. To mine the user info, we use the screen name of the twitter user. User info is generated in #2User_info_scraper.ipynb
